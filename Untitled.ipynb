# %%
ice_cream_rating = 6
sleeping_rating = 9

# %%
first_name = input("First name:")
last_name = input("Last name:")
my_name = first_name + " " + last_name
# Out:
# First name: Ivan
# Last name: Medina

# %%
happiness_rating = (ice_cream_rating + sleeping_rating) / 2

# %%
print (type (ice_cream_rating), type (first_name), type (happiness_rating))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %% [markdown]
# All of the data types make sense.
# None of the data types were different than I expected.

# %%
print ("My name is " + first_name + " and I give eating icecream a score of ", ice_cream_rating, " out of 10!")
print ("I am " + my_name + " and my sleeping enjoyment rating is ", sleeping_rating, " / 10!")
print ("Based on the factors above, my happiness rating is ", happiness_rating, " out of 10, or ", happiness_rating * 10, " %!")
# Out:
# My name is Ivan and I give eating icecream a score of  6  out of 10!
# I am Ivan Medina and my sleeping enjoyment rating is  9  / 10!
# Based on the factors above, my happiness rating is  7.5  out of 10, or  75.0  %!
